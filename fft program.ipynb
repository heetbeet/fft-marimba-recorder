# %%
# %run run_inits.ipy

RECORD = 1
X0, X1 = 50, 150
WAIT, DURATION = 2, 5
RESOLUTION = 1

def blur_level(frequency):
    return 1
    return np.clip(6000/frequency,
                   1, 30)
 
CUTTOFF_THRESHOLD = 0.00
LOGARITHMIC_F = False 
LOGARITHMIC_Y = True
DO_TRANSFORM = True
 
# %run run_fftprog.ipy   
ipd.Audio(data=a, rate=RATE, autoplay=True)
# Out:
# <style>.container { width:100% !important; }</style>
# Start. End. Opening file RECORDING.wav.
# Writing to RECORDING.wav.
# Finished writing to RECORDING.wav.
# Left to right: (1.0) 67.4|  (1.305) 88.0|  (1.524) 102.8|  (1.66) 112.0|  (1.821) 122.8|  (2.008) 135.4|  (2.189) 147.6|
# 1.000:   67.4
# 2.189:   147.6
# 2.189:   147.6
# <img src="data:image/png;base64,..." width="1100">
# Test workbook:  C:\Users\Public\marimba-sheet.xlsb
# We have --> C:\Users\Public\marimba-sheet.xlsb
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
